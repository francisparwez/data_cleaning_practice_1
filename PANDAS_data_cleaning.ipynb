# %% [markdown]
# ## Data Cleaning In Pandas

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = "/content/drive/MyDrive/DATA SCIENCE/DS IMP CODE/Alex The Analyst PANDAS Data Cleaning"

# %%
print(f"{PATH}/dataset.xlsx")
# Out:
# /content/drive/MyDrive/DATA SCIENCE/DS IMP CODE/Alex The Analyst PANDAS Data Cleaning/dataset.xlsx
